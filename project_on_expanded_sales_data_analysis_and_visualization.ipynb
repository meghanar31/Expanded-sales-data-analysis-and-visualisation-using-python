# %%
# importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#visualization

import seaborn as sns

#imperting the dataset

dataset=pd.read_csv('/content/expanded_sales_data_2500.csv')

#list of first five rows

dataset.head()
# Out:
#    item_id  user_id  rating   timestamp  gender    category     brand  year  \
# 0        1     3559       3  1640995200  Female     Cameras  Logitech  2017
# 1        2     4892       2  1640998800  Female  Headphones      Bose  2015
# 2        3     2807       2  1641002400  Female  Headphones    Archos  2016
# 3        4     4391       3  1641006000    Male    Security      Sony  2018
# 4        5     4552       4  1641009600    Male     Cameras    Archos  2018
#
#    month  quantity  unitprice  unit_cost region  amount  profit_margin
# 0     12         4        101      80.25  South     404          83.00
# 1      3         4        439     187.62  South    1756        1005.52
# 2      9         1        252      19.67   West     252         232.33
# 3      6         3        314     129.63   East     942         553.11
# 4      5         2         36     141.73   East      72        -211.46

# %% [markdown]
# ## To take a look at the first five rows we use the pandas function ".head()". similarly ".tail()" returns the last five observations of the data set.

# %%
# list of last five rows

dataset.tail()
# Out:
#       item_id  user_id  rating   timestamp  gender             category  \
# 2495     2496     4544       1  1649977200    Male  Wearable Technology
# 2496     2497     2169       3  1649980800    Male             Security
# 2497     2498     3293       4  1649984400    Male            Computers
# 2498     2499     4100       5  1649988000    Male              Cameras
# 2499     2500     2316       3  1649991600  Female  Wearable Technology
#
#        brand  year  month  quantity  unitprice  unit_cost region  amount  \
# 2495  Archos  2018      3         4         91     197.91  South     364
# 2496    Bose  2018      9         1        434      34.93   West     434
# 2497  Archos  2015     10         4        439     117.68   East    1756
# 2498    Sony  2018      9         2        463     150.34   West     926
# 2499    Bose  2017      2         4        294      89.62  North    1176
#
#       profit_margin
# 2495        -427.64
# 2496         399.07
# 2497        1285.28
# ...

# %% [markdown]
# ## To know the total number of rows and columns in the data set we use ".shape" as shown below

# %%
# shape

dataset.shape
# Out:
# (2500, 15)

# %% [markdown]
# # **Inference:**
# Dataset comprises 2500 Rows and 15 Columns
#
# To find whether they contain null values or not.

# %%
# to know the columns and their corresponding data types
# along with finding whether they contain null values or not.

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item_id        2500 non-null   int64
#  1   user_id        2500 non-null   int64
#  2   rating         2500 non-null   int64
#  3   timestamp      2500 non-null   int64
#  4   gender         2500 non-null   object
#  5   category       2500 non-null   object
#  6   brand          2500 non-null   object
#  7   year           2500 non-null   int64
#  8   month          2500 non-null   int64
#  9   quantity       2500 non-null   int64
#  10  unitprice      2500 non-null   int64
#  11  unit_cost      2500 non-null   float64
#  12  region         2500 non-null   object
#  13  amount         2500 non-null   int64
#  14  profit_margin  2500 non-null   float64
# dtypes: float64(2), int64(9), object(4)
# memory usage: 293.1+ KB

# %% [markdown]
# **Inference:**
# No variable column has null/missing values
# we can see the that the dataset contains 15 columns and 2500 rows.
#
# # The columns are as follows:
# 1.   item_id
# 2.   user_id
# 3.   rating
# 4.   timestamp
# 5.   gender
# 6.   category
# 7.   brand
# 8.   year
# 9.   month
# 10.  quantity
# 11.  untiprice
# 12.  unit_cost
# 13.  region
# 14.  amount
# 15.  profit_margin
#
#
#   # The data types of the columns are as follows:
# 1.   item_id =         int64
# 2.   user_id =          int64
# 3.   rating  =          int64
# 4.   timestamp =        int64
# 5.   gender =           object
# 6.   category =          object
# 7.   brand =           object
# 8.   year =             int64
# 9.   month =             int64
# 10.  quantity =          int64
# 11.  unitprice =         int64
# 12.  unit_cost =         float64
# 13.  region =           object
# 14.  amount =            int64
# 15.  profit_margin =     float64

# %% [markdown]
# ### We can see the columns user ID and Rating are of int64 data type, while the columns Product ID and Category are of object data type there are no null values in the dataset. The column Timestamp is of int64.
#
# ### The column Product ID is of object data type, but it is actually, the column Category is of object data type, but it is actually a string.
#
# ### To get a better understanding of he dataset, we can also see the statistical summary of the dataset using the function ".describe()".

# %%
# we can also see the statistical summary of the dataset

dataset['rating'].describe()
# Out:
# count    2500.000000
# mean        2.942800
# std         1.418003
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: rating, dtype: float64

# %% [markdown]
# # **Inference:**
# The statistical summary of the dataset gives us the following information:
#
# 1.   The mean ratings is 2.9
# 2.   The standard deviation of ratings is 1.41
# 3.   The minimum ratings is 1
# 4.   The 25th percentile of the ratings is 2
# 5.   The 50th percentile of the ratings is 3
# 6.   The 75th percentile of the ratings is 4
# 7.   The maximum ratings is 5

# %% [markdown]
# ## We can also see the number of unique users and items in the dataset

# %%
dataset.nunique()
# Out:
# item_id          2500
# user_id          1870
# rating              5
# timestamp        2500
# gender              2
# category            5
# brand               5
# year                4
# month              12
# quantity            4
# unitprice         478
# unit_cost        2362
# region              4
# amount            961
# profit_margin    2467
# dtype: int64

# %% [markdown]
# ## **Dealing with Missing Values**
#
# There can be multiple reasons why certain values are missing from the data. Reasons for the missing data from the dataset affect the approach of handling missing data.So it's necessary to understand why the data could be missing.

# %%
# check for missing values

dataset.isnull().sum()
# Out:
# item_id          0
# user_id          0
# rating           0
# timestamp        0
# gender           0
# category         0
# brand            0
# year             0
# month            0
# quantity         0
# unitprice        0
# unit_cost        0
# region           0
# amount           0
# profit_margin    0
# dtype: int64

# %% [markdown]
# ### The above output shows the checking sum of null values.

# %% [markdown]
# # **Finding Answers with the Data Using Visualizations**
#
# To make it easier to understand, we are going to use matplotlib and seabron that we earlier imported to visualize our results with simple bar charts. This will make it easier to answer questions that might arise from the data set.

# %% [markdown]
# ### 1. What was the best year of sales?

# %%
# what was the best year of sales

dataset.groupby('year')['amount'].count().plot(kind='bar', title='Year Wise Sales', xlabel='Year', ylabel='Sales Count')
# Out:
# <Axes: title={'center': 'Year Wise Sales'}, xlabel='Year', ylabel='Sales Count'>

# %% [markdown]
# ## 2. what was the best month of sales

# %%
# what was the best month of sales

dataset_2015_2018 = dataset[(dataset['year'] >= 2015) & (dataset['year']<= 2018)]
dataset_2015_2018.groupby('month')['rating'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## 3. what brand sold the most in 2015 to 2018

# %%
# what brand sold the most in 2015 to 2018

dataset_2015_2018 = dataset[(dataset['year'] >= 2015) & (dataset['year']<= 2018)]
dataset_2015_2018.groupby('brand')['amount'].sum().sort_values(ascending=False).head(10)\
.plot(kind='bar',title='Brand Wise Top 10 Sales 2015 to2018',y='amount')
# Out:
# <Axes: title={'center': 'Brand Wise Top 10 Sales 2015 to2018'}, xlabel='brand'>

# %%
# Create subplots with 2 rows and 2 columns
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
# Plot for 2016
top_selling_2016 = dataset[dataset['year'] ==2016].groupby('brand')['rating'].count().sort_values(ascending=False).head(10)
axs[0, 0].bar(top_selling_2016.index, top_selling_2016)
axs[0, 0].set_title('Top Selling Products in 2016')
axs[0, 0].tick_params(axis='x', rotation=45) # Rotate x-axis labels
# Plot for 2017
top_selling_2017 = dataset[dataset['year'] ==2017].groupby('brand')['rating'].count().sort_values(ascending=False).head(10)
axs[0, 1].bar(top_selling_2017.index, top_selling_2017)
axs[0, 1].set_title('Top Selling Products in 2017')
axs[0, 1].tick_params(axis='x', rotation=45) # Rotate x-axis labels
# Plot for 2018
top_selling_2018 = dataset[dataset['year'] == 2018].groupby('brand')['rating'].count().sort_values(ascending=False).head(10)
axs[1, 0].bar(top_selling_2018.index, top_selling_2018)
axs[1, 0].set_title('Top Selling Products in 2018')
axs[1, 0].tick_params(axis='x', rotation=45) # Rotate x-axis labels
# Hide the empty subplot
axs[1, 1].axis('off')
# Adjust layout for better appearance
plt.tight_layout()
# Show the plots
plt.show()

# %%
 # What product by category sold the most between 2015 to 2018?

dataset2015_2018 = dataset[(dataset['year'] >= 2015) & (dataset['year'] <= 2018)]
dataset2015_2018.groupby('category')['amount'].sum().sort_values(ascending=False).head(10).plot(kind='bar',title='Top 10 Most Sold Product Category 2015 to 2018')
# Out:
# <Axes: title={'center': 'Top 10 Most Sold Product Category 2015 to 2018'}, xlabel='category'>

# %%
# What product by brand name sold the least between 2015 to 2018?

dataset2015_2018 = dataset[(dataset['year'] >= 2015) & (dataset['year']<= 2018)]
dataset2015_2018.groupby('category')['amount'].sum().sort_values(ascending=True).head(10).plot(kind='bar',title='10 Least Sold Product Brand 2015 to 2018')
# Out:
# <Axes: title={'center': '10 Least Sold Product Brand 2015 to 2018'}, xlabel='category'>

# %%
# What product by brand name sold the least between 2015 to 2018?

dataset2015_2018 = dataset[(dataset['year'] >= 2015) & (dataset['year']<= 2018)]
dataset2015_2018.groupby('brand')['amount'].sum().sort_values(ascending=True).head(10).plot(kind='bar',title='10 Least Sold Product Brand 2015 to 2018')
# Out:
# <Axes: title={'center': '10 Least Sold Product Brand 2015 to 2018'}, xlabel='brand'>

# %%
# # the distribution of ratings

sns.countplot(x='rating', data=dataset)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
# What is the most rated brand name between 2015 to 2018?

dataset2015_2018 = dataset[(dataset['year'] >= 2015) & (dataset['year'] <= 2018)]
dataset2015_2018.groupby('brand')['rating'].mean().sort_values(ascending=False).head(10).plot(kind='bar',title='10 most rating Brand 2015 to 2018')
# Out:
# <Axes: title={'center': '10 most rating Brand 2015 to 2018'}, xlabel='brand'>

# %%
# category percentage sales

dataset.groupby('category')['amount'].sum().sort_values(ascending=False).head(5).plot(kind='pie', autopct='%1.1f%%',title='Top 5 category sales percentage')
# Out:
# <Axes: title={'center': 'Top 5 category sales percentage'}, ylabel='amount'>

# %%
# brand wise sales percentage

dataset.groupby('brand')['rating'].count().sort_values(ascending=False).head(5).plot(kind='pie', autopct='%1.1f%%',title='Top 5 Brand wise sales percentage')
# Out:
# <Axes: title={'center': 'Top 5 Brand wise sales percentage'}, ylabel='rating'>

# %%
# Gender wise customer distribution

gender_distribution = dataset['gender'].value_counts()
plt.pie(gender_distribution, labels=gender_distribution.index,
autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Gender wise customer Distribution')
plt.show()
